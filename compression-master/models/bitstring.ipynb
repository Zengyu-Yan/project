# %%
import numpy as np
import matplotlib.pyplot as plt
npzfile = np.load('foo.npz')
npzfile.files
# Out:
# ['arr_0']

# %%
print('arr_0 : ', npzfile['arr_0'])
# Out:
# arr_0 :  b'\n\xdd=\n$\n\x02MD\x12\x1e\n\x1c\n\x1abmshj2018-factorized-mse-1\n\x0b\n\x01\x03\x12\x06\x1a\x04\n\x02 0\n\r\n\x01\x02\x12\x08\x1a\x06\n\x04\x80\x04\x80\x06\n\x98=\n\x01\x01\x12\x92=\n\x8f=\n\x8c=)\xa4q\xc1\xcfD\x0c\xa6%D\x16q\xb1p\xf5i\xd1!\x8e\x1f\xaej\x06\x01\x02S\xd4O\xa6_\xad\x9f]\xe6\x8a\n\xcaz\x13\x05-\n\xf9\xcd\x19f5\x02R\x00*\xc2S\x9f\x9a\xc1y&T\x06\x0eg\xe9\x80u\xd8\x8b1j\nY$S\xdc\xe2\x908\x80\x1f\xa9I\xc7)\xcc\xfeu\xf8\xc7D\n\x7f\x9a\xf5agGeN\xc1a\xc4z\xf1\x8d"\x03\x8e\xb6z\xfeBs\x8c\xfa\xd0\x83\xa9\xb8\x89\xe2w$\x89\xec\xbb\x94\x89\\7Ku\x0c\xf7\xaasr\xd0&?&Kt\xce\xeb)\xbe}\xfd\x8e\xf9\xc7\xcf\x95\xc0\xc2v\x1e+\x84@i\xbfi\x9dc.\xc8\xe3\xf70\xe7\x97\xe5\xba\x82\x18\xda\xd5\x83\xbd\t\\+&(,\xe32\xac\xc9\t\x86\x16\x1d\x03\xf2\xfd"=\xbe\x86\x02\xc1\xf6\x89_\xb6\x08\xae\xa6\x15\x15\xdd\xb74RB\x9e\xef\xfb\x8c\xec\xbaZ\x19\xc66`\xec\xaa\xeb\xc00/d\xdar\xf23\x95/dps\x8c\xb2c\x14l\x94\xceL\xa8\x96\xc5\xac)\n\xba\xf4\x01t\xee\x1f\xc0\xe1\xaae\xfbV\xf5\xe8]\xe3\xc4\xc3\xc6\
# ...

# %%
plt.imshow(npzfile['arr_0'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e578dd9415fc> in <module>
# ----> 1 plt.imshow(npzfile['arr_0'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
# ...

# %%
npzfile['arr_0']
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-19-a744a10672d6> in <module>
# ----> 1 npzfile['arr_0']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     260                 return format.read_array(bytes,
#     261                                          allow_pickle=self.allow_pickle,
# --> 262                                          pickle_kwargs=self.pickle_kwargs)
#     263             else:
#     264                 return self.zip.read(key)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     758                     read_count = min(max_read_count, count - i)
#     759                     read_size = int(read_count * dtype.itemsize)
# --> 760                     data = _read_bytes(fp, read_size, "array data")
# ...

# %%
np.shape(npzfile['arr_0'][1])
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-20-32e87e171033> in <module>
# ----> 1 np.shape(npzfile['arr_0'][1])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     260                 return format.read_array(bytes,
#     261                                          allow_pickle=self.allow_pickle,
# --> 262                                          pickle_kwargs=self.pickle_kwargs)
#     263             else:
#     264                 return self.zip.read(key)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     758                     read_count = min(max_read_count, count - i)
#     759                     read_size = int(read_count * dtype.itemsize)
# --> 760                     data = _read_bytes(fp, read_size, "array data")
# ...

# %%
data = np.load('test.npz')      #类似于字典{‘arr_0’:a,’arr_1’:b,’arr_2’:c}
  print('arr_0 : ', data['arr_0'])
  print('arr_1 : ', data['arr_1'])
  print('arr_test: ', data['arr_test'])

    
    [array([b')xfa'],dtype=object), array([512, 768], dtype=int32), array([32, 48], dtype=int32)]
b'\n\xdd=\n\x98=\n\x01\x01\x12\x92=\n\x8f=\n\x8c=)\xa4q\xc1\xcfD\x0c\xa6%D\x16q\xb1p\xf5i\xd1!\x8e\x1f\xaej\x06\x01\x02S\xd4O\xa6_\xa

b'\n\xdd=\n\r\n\x01\x02\x12\x08\x1a\x06\n\x04\x80\x04\x80\x06\n$\n\x02MD\x12\x1e\n\x1c\n\x1abmshj2018-factorized-mse-1\
b'\n\xdd=\n\x0b\n\x01\x03\x12\x06\x1a\x04\n\x02 0\n$\n\x02MD\x12\x1e\n\x1c\n\x1abmshj2018-factorized-mse-1\

[b')\xa4q\xc1\xcfD\x0c\xa6%D\x16q\xb1p\xf5i\xd1!\x8e\x1f\xaej\x06\x01\x02S\xd4O\xa6_\xad\x9f]\xe6\x8a\n\xcaz\x13
 
 
arrays[0]: [b')\xa4q\xc1\xcfD\x0c\xa6%D\x16q\xb1p\xf5i\xd1
packed.string: b'\n\xdd=\n\x98=\n\x01\x01\x12\x92=\n\x8f=\n\x8c=)\xa4q\
bitstring: b'\n\xdd=\n\r\n\x01\x02\x12\x08\x1a\x06\n\x04\x80\x04\x80\x06\n$\n\x02MD\x12\x1e\n\x1c\n\x1abmshj2018-facto
b'\n\xdd=\n\x0b\n\x01\x03\x12\x06\x1a\x04\n\x02 0\n\r\n\x01\x02\x12\x08\x1a\x06\n\x04\x80\x04\x80\x06\n\x98=\n\
